# %%
# !pip install torch torchvision

#this notebook works—takes pretrained model, extract features on train then validation.
#then, uses these train features to train kmeans, and then predict on the validation features
#train on train -> predict on valid makes it worse
#train/predict on valid makes it better (this is not valid but technically this should mean our features are valid, right?)
#train on train + valid, predict on valid. exactly the same as train/predict on valid, perhpas meaning train on train is useless
from skimage.segmentation import watershed, felzenszwalb
from skimage.filters import sobel
import pandas as pd
from pathlib import Path
import cv2
import pickle
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from skimage.filters import rank
from scipy import ndimage as ndi
from skimage.morphology import disk
import sklearn.metrics
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# downloading the images

# !wget https://challengedata.ens.fr/media/public/train-images.zip
# !wget https://challengedata.ens.fr/media/public/test-images.zip
# !wget https://challengedata.ens.fr/media/public/label_Hnl61pT.csv -O y_train.csv
# Out:
# --2025-02-28 00:37:46--  https://challengedata.ens.fr/media/public/train-images.zip
# Resolving challengedata.ens.fr (challengedata.ens.fr)... 129.199.99.148
# Connecting to challengedata.ens.fr (challengedata.ens.fr)|129.199.99.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52391647 (50M) [application/zip]
# Saving to: ‘train-images.zip’
#
# train-images.zip    100%[===================>]  49.96M  12.6MB/s    in 4.2s
#
# 2025-02-28 00:37:51 (11.8 MB/s) - ‘train-images.zip’ saved [52391647/52391647]
#
# --2025-02-28 00:37:51--  https://challengedata.ens.fr/media/public/test-images.zip
# Resolving challengedata.ens.fr (challengedata.ens.fr)... 129.199.99.148
# Connecting to challengedata.ens.fr (challengedata.ens.fr)|129.199.99.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12803342 (12M) [application/zip]
# Saving to: ‘test-images.zip’
#
# test-images.zip     100%[===================>]  12.21M  8.96MB/s    in 1.4s
#
# 2025-02-28 00:37:53 (8.96 MB/s) - ‘test-images.zip’ saved [12803342/12803342]
#
# --2025-02-28 00:37:53--  https://challengedata.ens.fr/media/public/label_Hnl61pT.csv
# Resolving challengedata.ens.fr (challengedata.ens.fr)... 129.199.99.148
# Connecting to challengedata.ens.fr (challengedata.ens.fr)|129.199.99.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267819968 (255M) [text/csv]
# Saving to: ‘y_train.csv’
#
# y_train.csv         100%[===================>] 255.41M  21.4MB/s    in 13s
#
# 2025-02-28 00:38:07 (19.5 MB/s) - ‘y_train.csv’ saved [267819968/267819968]

# %%
# !unzip train-images.zip
# !unzip test-images.zip
# Out:
# Archive:  train-images.zip
#    creating: train-images/
#   inflating: train-images/348.png
#   inflating: train-images/1804.png
#  extracting: train-images/1810.png
#  extracting: train-images/1186.png
#  extracting: train-images/412.png
#  extracting: train-images/374.png
#   inflating: train-images/1838.png
#  extracting: train-images/360.png
#  extracting: train-images/406.png
#   inflating: train-images/1192.png
#  extracting: train-images/1179.png
#  extracting: train-images/1145.png
#  extracting: train-images/1623.png
#  extracting: train-images/1637.png
#  extracting: train-images/1151.png
#  extracting: train-images/638.png
#   inflating: train-images/176.png
#  extracting: train-images/88.png
#  extracting: train-images/610.png
#  extracting: train-images/1384.png
#  extracting: train-images/1390.png
#  extracting: train-images/604.png
#   inflating: train-images/162.png
#  extracting: train-images/189.png
#  extracting: train-images/837.png
#  extracting: train-images/77.png
#  extracting: train-images/823.png
#   inflating: train-images/63.png
#  extracting: train-images/1409.png
#  extracting: train-images/1421.png
#  extracting: train-images/1347.png
#  extracting: train-images/1353.png
#  extracting: train-images/1435.png
#  extracting: train-images/980.png
#  extracting: train-images/758.png
#  extracting: train-images/994.png
#  extracting: train-images/1596.png
#  extracting: train-images/764.png
#  extracting: train-images/770.png
#  extracting: train-images/1582.png
#  extracting: train-images/1569.png
#  extracting: train-images/943.png
#  extracting: train-images/957.png
#  extracting: train-images/1555.png
#  extracting: train-images/1233.png
#  extracting: train-images/1227.png
#   inflating: train-images/1541.png
#   inflating: train-images/1970.png
#   inflating: train-images/1964.png
#  extracting: train-images/228.png
#   inflating: train-images/566.png
#   inflating: train-images/1794.png
#  extracting: train-images/200.png
#   inflating: train-images/1958.png
#  extracting: train-images/214.png
#  extracting: train-images/1780.png
#  extracting: train-images/572.png
#  extracting: train-images/599.png
#  extracting: train-images/1019.png
#  extracting: train-images/1031.png
#  extracting: train-images/1757.png
#  extracting: train-images/1743.png
#  extracting: train-images/1025.png
#   inflating: train-images/1742.png
#  extracting: train-images/1024.png
#  extracting: train-images/1030.png
#  extracting: train-images/1756.png
#  extracting: train-images/1018.png
#  extracting: train-images/598.png
#  extracting: train-images/1781.png
#  extracting: train-images/215.png
#   inflating: train-images/1959.png
#  extracting: train-images/573.png
#  extracting: train-images/567.png
#  extracting: train-images/201.png
#  extracting: train-images/1795.png
#  extracting: train-images/229.png
#   inflating: train-images/1965.png
#  extracting: train-images/1971.png
#   inflating: train-images/1226.png
#  extracting: train-images/1540.png
#  extracting: train-images/1554.png
#  extracting: train-images/1232.png
#  extracting: train-images/956.png
#  extracting: train-images/1568.png
#   inflating: train-images/942.png
#  extracting: train-images/771.png
#   inflating: train-images/1583.png
#  extracting: train-images/1597.png
#  extracting: train-images/765.png
#  extracting: train-images/995.png
#  extracting: train-images/759.png
#  extracting: train-images/981.png
#  extracting: train-images/1352.png
#  extracting: train-images/1434.png
#  extracting: train-images/1420.png
#  extracting: train-images/1346.png
#  extracting: train-images/62.png
#   inflating: train-images/822.png
#   inflating: train-images/1408.png
#  extracting: train-images/188.png
#  extracting: train-images/76.png
#  extracting: train-images/836.png
#  extracting: train-images/605.png
#  extracting: train-images/1391.png
#   inflating: train-images/163.png
#   inflating: train-images/177.png
#  extracting: train-images/1385.png
#  extracting: train-images/611.png
#  extracting: train-images/89.png
#  extracting: train-images/639.png
#  extracting: train-images/1636.png
#   inflating: train-images/1150.png
#  extracting: train-images/1144.png
#   inflating: train-images/1622.png
#  extracting: train-images/1178.png
#   inflating: train-images/361.png
#  extracting: train-images/1193.png
#  extracting: train-images/407.png
#  extracting: train-images/413.png
#  extracting: train-images/1187.png
#  extracting: train-images/1839.png
#  extracting: train-images/375.png
#  extracting: train-images/1811.png
#   inflating: train-images/1805.png
#  extracting: train-images/349.png
#   inflating: train-images/439.png
#   inflating: train-images/1813.png
#  extracting: train-images/1807.png
#   inflating: train-images/405.png
#   inflating: train-images/1191.png
#  extracting: train-images/363.png
#  extracting: train-images/377.png
#  extracting: train-images/1185.png
#   inflating: train-images/411.png
#  extracting: train-images/1608.png
#   inflating: train-images/388.png
#   inflating: train-images/1152.png
#   inflating: train-images/1634.png
#   inflating: train-images/1620.png
#  extracting: train-images/1146.png
#  extracting: train-images/149.png
#   inflating: train-images/161.png
#  extracting: train-images/1393.png
#   inflating: train-images/607.png
#  extracting: train-images/613.png
#  extracting: train-images/1387.png
#   inflating: train-images/175.png
#  extracting: train-images/820.png
#  extracting: train-images/60.png
#  extracting: train-images/834.png
#  extracting: train-images/74.png
#  extracting: train-images/1378.png
#  extracting: train-images/1436.png
#   inflating: train-images/1350.png
#  extracting: train-images/808.png
#  extracting: train-images/48.png
#  extracting: train-images/1344.png
#  extracting: train-images/1422.png
#  extracting: train-images/997.png
#  extracting: train-images/983.png
#   inflating: train-images/1581.png
#  extracting: train-images/773.png
#   inflating: train-images/767.png
#  extracting: train-images/1595.png
#  extracting: train-images/1218.png
#   inflating: train-images/954.png
#  extracting: train-images/798.png
#  extracting: train-images/940.png
#   inflating: train-images/1542.png
#   inflating: train-images/1224.png
#  extracting: train-images/968.png
#   inflating: train-images/1230.png
#  extracting: train-images/1556.png
#   inflating: train-images/1967.png
#  extracting: train-images/1973.png
#   inflating: train-images/559.png
#  extracting: train-images/571.png
#   inflating: train-images/217.png
#  extracting: train-images/1783.png
#  extracting: train-images/1797.png
#  extracting: train-images/203.png
#   inflating: train-images/565.png
#  extracting: train-images/1768.png
#  extracting: train-images/1026.png
#  extracting: train-images/1740.png
#  extracting: train-images/1998.png
#  extracting: train-images/1754.png
#  extracting: train-images/1032.png
#  extracting: train-images/1755.png
#  extracting: train-images/1033.png
#   inflating: train-images/1027.png
#   inflating: train-images/1999.png
#  extracting: train-images/1741.png
#  extracting: train-images/1769.png
#  extracting: train-images/202.png
#  extracting: train-images/1796.png
#  extracting: train-images/564.png
#  extracting: train-images/570.png
#  extracting: train-images/1782.png
#   inflating: train-images/216.png
#  extracting: train-images/1972.png
#  extracting: train-images/558.png
#  extracting: train-images/1966.png
#  extracting: train-images/1231.png
#  extracting: train-images/1557.png
#  extracting: train-images/1543.png
#  extracting: train-images/969.png
#   inflating: train-images/1225.png
#   inflating: train-images/941.png
#   inflating: train-images/799.png
#  extracting: train-images/955.png
#  extracting: train-images/1219.png
#   inflating: train-images/766.png
#   inflating: train-images/1594.png
#  extracting: train-images/1580.png
#  extracting: train-images/772.png
#  extracting: train-images/982.png
#  extracting: train-images/996.png
#  extracting: train-images/1345.png
#  extracting: train-images/49.png
#  extracting: train-images/809.png
#  extracting: train-images/1423.png
#  extracting: train-images/1437.png
#   inflating: train-images/1351.png
#  extracting: train-images/1379.png
#  extracting: train-images/75.png
#   inflating: train-images/835.png
#  extracting: train-images/61.png
#   inflating: train-images/821.png
#  extracting: train-images/1386.png
#   inflating: train-images/612.png
#   inflating: train-images/174.png
#  extracting: train-images/160.png
#   inflating: train-images/606.png
#  extracting: train-images/1392.png
#  extracting: train-images/148.png
#   inflating: train-images/1621.png
#  extracting: train-images/1147.png
#  extracting: train-images/1153.png
#  extracting: train-images/1635.png
#   inflating: train-images/389.png
#  extracting: train-images/1609.png
#  extracting: train-images/376.png
#   inflating: train-images/410.png
#  extracting: train-images/1184.png
#  extracting: train-images/1190.png
#   inflating: train-images/404.png
#  extracting: train-images/362.png
#  extracting: train-images/1806.png
#  extracting: train-images/438.png
#  extracting: train-images/1812.png
#   inflating: train-images/366.png
#  extracting: train-images/400.png
#  extracting: train-images/1194.png
#  extracting: train-images/1180.png
#  extracting: train-images/414.png
#  extracting: train-images/372.png
#  extracting: train-images/1816.png
#  extracting: train-images/428.png
#   inflating: train-images/1802.png
#  extracting: train-images/1631.png
#   inflating: train-images/1157.png
#  extracting: train-images/1143.png
#  extracting: train-images/1625.png
#  extracting: train-images/399.png
#  extracting: train-images/1619.png
#  extracting: train-images/1396.png
#  extracting: train-images/602.png
#   inflating: train-images/164.png
#  extracting: train-images/170.png
#  extracting: train-images/616.png
#   inflating: train-images/1382.png
#  extracting: train-images/158.png
#  extracting: train-images/819.png
#   inflating: train-images/1355.png
#  extracting: train-images/59.png
#  extracting: train-images/1433.png
#  extracting: train-images/1427.png
#  extracting: train-images/1341.png
#  extracting: train-images/825.png
#  extracting: train-images/1369.png
#  extracting: train-images/65.png
#  extracting: train-images/831.png
#  extracting: train-images/71.png
#   inflating: train-images/776.png
#  extracting: train-images/1584.png
#  extracting: train-images/1590.png
#  extracting: train-images/762.png
#   inflating: train-images/992.png
#  extracting: train-images/986.png
#  extracting: train-images/1221.png
#  extracting: train-images/1547.png
#  extracting: train-images/1553.png
#   inflating: train-images/1235.png
#   inflating: train-images/979.png
#   inflating: train-images/789.png
#   inflating: train-images/951.png
#   inflating: train-images/1209.png
#   inflating: train-images/945.png
#   inflating: train-images/212.png
#  extracting: train-images/1786.png
#  extracting: train-images/574.png
#   inflating: train-images/560.png
#  extracting: train-images/1792.png
#   inflating: train-images/206.png
#  extracting: train-images/1962.png
#  extracting: train-images/548.png
#   inflating: train-images/1976.png
#  extracting: train-images/1745.png
#  extracting: train-images/1023.png
#  extracting: train-images/1037.png
#  extracting: train-images/1751.png
#   inflating: train-images/1989.png
#  extracting: train-images/1779.png
#  extracting: train-images/1778.png
#  extracting: train-images/1036.png
#  extracting: train-images/1988.png
#  extracting: train-images/1750.png
#  extracting: train-images/1744.png
#  extracting: train-images/1022.png
#  extracting: train-images/1977.png
#  extracting: train-images/1963.png
#   inflating: train-images/549.png
#   inflating: train-images/561.png
#   inflating: train-images/207.png
#   inflating: train-images/1793.png
#  extracting: train-images/1787.png
#   inflating: train-images/213.png
#  extracting: train-images/575.png
#   inflating: train-images/944.png
#  extracting: train-images/1208.png
#  extracting: train-images/950.png
#  extracting: train-images/788.png
#   inflating: train-images/1552.png
#   inflating: train-images/978.png
#  extracting: train-images/1234.png
#  extracting: train-images/1220.png
#  extracting: train-images/1546.png
#   inflating: train-images/987.png
#  extracting: train-images/993.png
#   inflating: train-images/1591.png
#  extracting: train-images/763.png
#  extracting: train-images/777.png
#  extracting: train-images/1585.png
#  extracting: train-images/70.png
#   inflating: train-images/830.png
#  extracting: train-images/64.png
#   inflating: train-images/1368.png
#  extracting: train-images/824.png
#  extracting: train-images/1426.png
#  extracting: train-images/1340.png
#  extracting: train-images/58.png
#  extracting: train-images/1354.png
#  extracting: train-images/818.png
#   inflating: train-images/1432.png
#  extracting: train-images/159.png
#  extracting: train-images/171.png
#   inflating: train-images/1383.png
#  extracting: train-images/617.png
#   inflating: train-images/603.png
#  extracting: train-images/1397.png
#   inflating: train-images/165.png
#  extracting: train-images/1618.png
#   inflating: train-images/398.png
#  extracting: train-images/1142.png
#  extracting: train-images/1624.png
#  extracting: train-images/1630.png
#  extracting: train-images/1156.png
#   inflating: train-images/429.png
#  extracting: train-images/1803.png
#  extracting: train-images/1817.png
#  extracting: train-images/415.png
#   inflating: train-images/1181.png
#  extracting: train-images/373.png
#  extracting: train-images/367.png
#   inflating: train-images/1195.png
#  extracting: train-images/401.png
#   inflating: train-images/371.png
#  extracting: train-images/1183.png
#  extracting: train-images/417.png
#   inflating: train-images/403.png
#  extracting: train-images/1197.png
#   inflating: train-images/365.png
#   inflating: train-images/1829.png
#   inflating: train-images/1801.png
#  extracting: train-images/359.png
#  extracting: train-images/1815.png
#  extracting: train-images/1626.png
#  extracting: train-images/1140.png
#  extracting: train-images/1154.png
#  extracting: train-images/1632.png
#  extracting: train-images/1168.png
#  extracting: train-images/615.png
#  extracting: train-images/1381.png
#   inflating: train-images/173.png
#   inflating: train-images/167.png
#  extracting: train-images/1395.png
#  extracting: train-images/601.png
#  extracting: train-images/99.png
#   inflating: train-images/629.png
#  extracting: train-images/1342.png
#  extracting: train-images/1424.png
#  extracting: train-images/1430.png
#  extracting: train-images/8.png
#   inflating: train-images/1356.png
#  extracting: train-images/832.png
#   inflating: train-images/72.png
#  extracting: train-images/1418.png
#   inflating: train-images/198.png
#  extracting: train-images/826.png
#  extracting: train-images/66.png
#  extracting: train-images/761.png
#   inflating: train-images/1593.png
#  extracting: train-images/1587.png
#  extracting: train-images/775.png
#  extracting: train-images/985.png
#   inflating: train-images/991.png
#  extracting: train-images/749.png
#   inflating: train-images/1236.png
#  extracting: train-images/1550.png
#  extracting: train-images/1544.png
#  extracting: train-images/1222.png
#   inflating: train-images/946.png
#  extracting: train-images/1578.png
#   inflating: train-images/952.png
#  extracting: train-images/1949.png
#  extracting: train-images/1791.png
#  extracting: train-images/205.png
#   inflating: train-images/563.png
#   inflating: train-images/577.png
#   inflating: train-images/211.png
#  extracting: train-images/1785.png
#  extracting: train-images/1975.png
#  extracting: train-images/239.png
#   inflating: train-images/1961.png
#  extracting: train-images/1752.png
#   inflating: train-images/1034.png
#  extracting: train-images/1020.png
#  extracting: train-images/1746.png
#  extracting: train-images/1008.png
#   inflating: train-images/588.png
#   inflating: train-images/589.png
#   inflating: train-images/1009.png
#  extracting: train-images/1021.png
#  extracting: train-images/1747.png
#  extracting: train-images/1753.png
#   inflating: train-images/1035.png
#   inflating: train-images/1960.png
#  extracting: train-images/238.png
#  extracting: train-images/1974.png
#  extracting: train-images/576.png
#  extracting: train-images/1784.png
#   inflating: train-images/210.png
#  extracting: train-images/204.png
#  extracting: train-images/1790.png
#  extracting: train-images/1948.png
#   inflating: train-images/562.png
#  extracting: train-images/1579.png
#   inflating: train-images/953.png
#  extracting: train-images/947.png
#  extracting: train-images/1545.png
#   inflating: train-images/1223.png
#  extracting: train-images/1237.png
#  extracting: train-images/1551.png
#  extracting: train-images/748.png
#   inflating: train-images/990.png
#  extracting: train-images/984.png
#  extracting: train-images/1586.png
#  extracting: train-images/774.png
#  extracting: train-images/760.png
#   inflating: train-images/1592.png
#   inflating: train-images/199.png
#  extracting: train-images/67.png
#  extracting: train-images/827.png
#   inflating: train-images/73.png
#  extracting: train-images/833.png
#   inflating: train-images/1419.png
#  extracting: train-images/9.png
#   inflating: train-images/1431.png
#  extracting: train-images/1357.png
#  extracting: train-images/1343.png
#  extracting: train-images/1425.png
#   inflating: train-images/628.png
#   inflating: train-images/166.png
#  extracting: train-images/98.png
#   inflating: train-images/600.png
#  extracting: train-images/1394.png
#   inflating: train-images/1380.png
#  extracting: train-images/614.png
#   inflating: train-images/172.png
#  extracting: train-images/1169.png
#  extracting: train-images/1155.png
#   inflating: train-images/1633.png
#   inflating: train-images/1627.png
#  extracting: train-images/1141.png
#   inflating: train-images/1814.png
#  extracting: train-images/358.png
#  extracting: train-images/1800.png
#  extracting: train-images/1196.png
#   inflating: train-images/402.png
#  extracting: train-images/1828.png
#   inflating: train-images/364.png
#  extracting: train-images/370.png
#  extracting: train-images/416.png
#   inflating: train-images/1182.png
#  extracting: train-images/1867.png
#  extracting: train-images/459.png
#  extracting: train-images/1873.png
#  extracting: train-images/1683.png
#  extracting: train-images/317.png
#  extracting: train-images/471.png
#  extracting: train-images/465.png
#   inflating: train-images/303.png
#  extracting: train-images/1697.png
#   inflating: train-images/1668.png
#  extracting: train-images/1898.png
#  extracting: train-images/1640.png
#   inflating: train-images/1126.png
#  extracting: train-images/1132.png
#  extracting: train-images/1654.png
#  extracting: train-images/897.png
#   inflating: train-images/129.png
#  extracting: train-images/883.png
#  extracting: train-images/673.png
#   inflating: train-images/115.png
#  extracting: train-images/1481.png
#  extracting: train-images/1495.png
#   inflating: train-images/101.png
#  extracting: train-images/667.png
#  extracting: train-images/854.png
#  extracting: train-images/14.png
#  extracting: train-images/1318.png
#  extracting: train-images/840.png
#  extracting: train-images/698.png
#  extracting: train-images/868.png
#   inflating: train-images/28.png
#  extracting: train-images/1324.png
#   inflating: train-images/1442.png
#  extracting: train-images/1456.png
#  extracting: train-images/1330.png
#  extracting: train-images/707.png
#   inflating: train-images/1293.png
#   inflating: train-images/1287.png
#  extracting: train-images/713.png
#   inflating: train-images/920.png
#  extracting: train-images/1278.png
#  extracting: train-images/934.png
#  extracting: train-images/1250.png
#  extracting: train-images/1536.png
#  extracting: train-images/1522.png
#  extracting: train-images/1244.png
#  extracting: train-images/908.png
#  extracting: train-images/1913.png
#  extracting: train-images/539.png
#  extracting: train-images/1907.png
#  extracting: train-images/263.png
#  extracting: train-images/1091.png
#   inflating: train-images/505.png
#  extracting: train-images/511.png
#  extracting: train-images/1085.png
#  extracting: train-images/277.png
#  extracting: train-images/1708.png
#   inflating: train-images/288.png
#  extracting: train-images/1734.png
#   inflating: train-images/1052.png
#  extracting: train-images/1046.png
#  extracting: train-images/1720.png
#  extracting: train-images/1047.png
#  extracting: train-images/1721.png
#  extracting: train-images/1735.png
#   inflating: train-images/1053.png
#  extracting: train-images/289.png
#   inflating: train-images/1709.png
#  extracting: train-images/1084.png
#  extracting: train-images/510.png
#   inflating: train-images/276.png
#  extracting: train-images/262.png
#   inflating: train-images/504.png
#  extracting: train-images/1090.png
#  extracting: train-images/1906.png
#  extracting: train-images/1912.png
#  extracting: train-images/538.png
#  extracting: train-images/1523.png
#  extracting: train-images/909.png
#  extracting: train-images/1245.png
#  extracting: train-images/1251.png
#   inflating: train-images/1537.png
#  extracting: train-images/935.png
#  extracting: train-images/1279.png
#  extracting: train-images/921.png
#   inflating: train-images/712.png
#  extracting: train-images/1286.png
#  extracting: train-images/1292.png
#  extracting: train-images/706.png
#  extracting: train-images/1457.png
#  extracting: train-images/1331.png
#  extracting: train-images/1325.png
#  extracting: train-images/29.png
#  extracting: train-images/869.png
#   inflating: train-images/1443.png
#  extracting: train-images/699.png
#  extracting: train-images/841.png
#   inflating: train-images/1319.png
#  extracting: train-images/15.png
#  extracting: train-images/855.png
#   inflating: train-images/100.png
#  extracting: train-images/1494.png
#  extracting: train-images/666.png
#  extracting: train-images/672.png
#  extracting: train-images/1480.png
#   inflating: train-images/114.png
#  extracting: train-images/882.png
#  extracting: train-images/896.png
#   inflating: train-images/128.png
#  extracting: train-images/1133.png
#  extracting: train-images/1655.png
#  extracting: train-images/1641.png
#   inflating: train-images/1899.png
#   inflating: train-images/1127.png
#  extracting: train-images/1669.png
#  extracting: train-images/464.png
#  extracting: train-images/1696.png
#   inflating: train-images/302.png
#  extracting: train-images/316.png
#  extracting: train-images/1682.png
#   inflating: train-images/470.png
#  extracting: train-images/458.png
#  extracting: train-images/1872.png
#  extracting: train-images/1866.png
#  extracting: train-images/1870.png
#   inflating: train-images/328.png
#   inflating: train-images/1864.png
#  extracting: train-images/300.png
#  extracting: train-images/1694.png
#  extracting: train-images/466.png
#   inflating: train-images/472.png
#   inflating: train-images/1680.png
#  extracting: train-images/314.png
#   inflating: train-images/1858.png
#  extracting: train-images/499.png
#   inflating: train-images/1119.png
#  extracting: train-images/1657.png
#   inflating: train-images/1131.png
#   inflating: train-images/1125.png
#  extracting: train-images/1643.png
#  extracting: train-images/658.png
#   inflating: train-images/880.png
#   inflating: train-images/894.png
#  extracting: train-images/664.png
#  extracting: train-images/1496.png
#  extracting: train-images/102.png
#  extracting: train-images/116.png
#  extracting: train-images/1482.png
#  extracting: train-images/670.png
#  extracting: train-images/843.png
#  extracting: train-images/1469.png
#  extracting: train-images/857.png
#  extracting: train-images/17.png
#  extracting: train-images/1333.png
#  extracting: train-images/1455.png
#   inflating: train-images/1441.png
#   inflating: train-images/1327.png
#  extracting: train-images/738.png
#  extracting: train-images/1284.png
#  extracting: train-images/710.png
#  extracting: train-images/704.png
#   inflating: train-images/1290.png
#  extracting: train-images/937.png
#  extracting: train-images/1509.png
#  extracting: train-images/923.png
#  extracting: train-images/1247.png
#  extracting: train-images/1521.png
#   inflating: train-images/1535.png
#  extracting: train-images/1253.png
#  extracting: train-images/1904.png
#  extracting: train-images/248.png
#  extracting: train-images/1910.png
#  extracting: train-images/1938.png
#   inflating: train-images/274.png
#  extracting: train-images/512.png
#   inflating: train-images/1086.png
#   inflating: train-images/1092.png
#   inflating: train-images/506.png
#   inflating: train-images/260.png
#   inflating: train-images/1079.png
#  extracting: train-images/1723.png
#  extracting: train-images/1045.png
#  extracting: train-images/1051.png
#  extracting: train-images/1737.png
#  extracting: train-images/1050.png
#  extracting: train-images/1736.png
#  extracting: train-images/1722.png
#  extracting: train-images/1044.png
#   inflating: train-images/1078.png
#   inflating: train-images/507.png
#   inflating: train-images/1093.png
#   inflating: train-images/261.png
#   inflating: train-images/275.png
#  extracting: train-images/1939.png
#   inflating: train-images/1087.png
#  extracting: train-images/513.png
#  extracting: train-images/1911.png
#  extracting: train-images/249.png
#  extracting: train-images/1905.png
#  extracting: train-images/1534.png
#  extracting: train-images/1252.png
#  extracting: train-images/1246.png
#  extracting: train-images/1520.png
#  extracting: train-images/1508.png
#  extracting: train-images/922.png
#  extracting: train-images/936.png
#  extracting: train-images/1291.png
#  extracting: train-images/705.png
#   inflating: train-images/711.png
#  extracting: train-images/1285.png
#  extracting: train-images/739.png
#   inflating: train-images/1440.png
#  extracting: train-images/1326.png
#  extracting: train-images/1332.png
#  extracting: train-images/1454.png
#  extracting: train-images/16.png
#   inflating: train-images/856.png
#  extracting: train-images/842.png
#  extracting: train-images/1468.png
#  extracting: train-images/1483.png
#  extracting: train-images/117.png
#  extracting: train-images/671.png
#  extracting: train-images/665.png
#  extracting: train-images/103.png
#  extracting: train-images/1497.png
#  extracting: train-images/895.png
#  extracting: train-images/881.png
#  extracting: train-images/659.png
#   inflating: train-images/1124.png
#  extracting: train-images/1642.png
#  extracting: train-images/1656.png
#   inflating: train-images/1130.png
#   inflating: train-images/1118.png
#  extracting: train-images/498.png
#  extracting: train-images/473.png
#  extracting: train-images/1859.png
#  extracting: train-images/315.png
#   inflating: train-images/1681.png
#  extracting: train-images/1695.png
#  extracting: train-images/301.png
#  extracting: train-images/467.png
#  extracting: train-images/1865.png
#   inflating: train-images/329.png
#  extracting: train-images/1871.png
#  extracting: train-images/463.png
#   inflating: train-images/305.png
#  extracting: train-images/1691.png
#  extracting: train-images/1849.png
#  extracting: train-images/1685.png
#  extracting: train-images/311.png
#  extracting: train-images/477.png
#  extracting: train-images/339.png
#  extracting: train-images/1875.png
#  extracting: train-images/1861.png
#  extracting: train-images/1134.png
#  extracting: train-images/1652.png
#   inflating: train-images/1646.png
#  extracting: train-images/1120.png
#  extracting: train-images/1108.png
#   inflating: train-images/488.png
#  extracting: train-images/1493.png
#  extracting: train-images/107.png
#  extracting: train-images/661.png
#   inflating: train-images/675.png
#   inflating: train-images/113.png
#  extracting: train-images/1487.png
#  extracting: train-images/885.png
#  extracting: train-images/649.png
#  extracting: train-images/891.png
#   inflating: train-images/1450.png
#   inflating: train-images/1336.png
#  extracting: train-images/1322.png
#  extracting: train-images/1444.png
#  extracting: train-images/846.png
#  extracting: train-images/852.png
#   inflating: train-images/12.png
#  extracting: train-images/1478.png
#   inflating: train-images/1281.png
#   inflating: train-images/715.png
#  extracting: train-images/701.png
#  extracting: train-images/1295.png
#  extracting: train-images/729.png
#  extracting: train-images/1524.png
#  extracting: train-images/1242.png
#  extracting: train-images/1256.png
#  extracting: train-images/1530.png
#   inflating: train-images/1518.png
#  extracting: train-images/932.png
#   inflating: train-images/926.png
#  extracting: train-images/517.png
#   inflating: train-images/1083.png
#  extracting: train-images/271.png
#  extracting: train-images/1929.png
#  extracting: train-images/265.png
#  extracting: train-images/1097.png
#  extracting: train-images/503.png
#   inflating: train-images/1901.png
#  extracting: train-images/1915.png
#   inflating: train-images/259.png
#  extracting: train-images/1040.png
#  extracting: train-images/1726.png
#  extracting: train-images/1732.png
#   inflating: train-images/1054.png
#  extracting: train-images/1068.png
#  extracting: train-images/1069.png
#  extracting: train-images/1733.png
#   inflating: train-images/1055.png
#  extracting: train-images/1041.png
#  extracting: train-images/1727.png
#  extracting: train-images/258.png
#  extracting: train-images/1914.png
#   inflating: train-images/1900.png
#  extracting: train-images/264.png
#  extracting: train-images/1928.png
#  extracting: train-images/502.png
#  extracting: train-images/1096.png
#   inflating: train-images/1082.png
#   inflating: train-images/516.png
#   inflating: train-images/270.png
#   inflating: train-images/927.png
#   inflating: train-images/1519.png
#  extracting: train-images/933.png
#  extracting: train-images/1257.png
#  extracting: train-images/1531.png
#  extracting: train-images/1525.png
#  extracting: train-images/1243.png
#  extracting: train-images/728.png
#   inflating: train-images/1294.png
#  extracting: train-images/700.png
#  extracting: train-images/714.png
#  extracting: train-images/1280.png
#  extracting: train-images/13.png
#  extracting: train-images/853.png
#  extracting: train-images/1479.png
#  extracting: train-images/847.png
#  extracting: train-images/1323.png
#  extracting: train-images/1445.png
#   inflating: train-images/1451.png
#  extracting: train-images/1337.png
#  extracting: train-images/890.png
#   inflating: train-images/648.png
#  extracting: train-images/884.png
#  extracting: train-images/674.png
#   inflating: train-images/1486.png
#  extracting: train-images/112.png
#  extracting: train-images/106.png
#  extracting: train-images/1492.png
#  extracting: train-images/660.png
#   inflating: train-images/489.png
#  extracting: train-images/1109.png
#   inflating: train-images/1647.png
#  extracting: train-images/1121.png
#  extracting: train-images/1135.png
#  extracting: train-images/1653.png
#  extracting: train-images/1860.png
#  extracting: train-images/1874.png
#  extracting: train-images/338.png
#  extracting: train-images/310.png
#  extracting: train-images/1684.png
#  extracting: train-images/476.png
#  extracting: train-images/462.png
#  extracting: train-images/1848.png
#  extracting: train-images/1690.png
#   inflating: train-images/304.png
#  extracting: train-images/474.png
#  extracting: train-images/1686.png
#  extracting: train-images/312.png
#  extracting: train-images/306.png
#  extracting: train-images/1692.png
#   inflating: train-images/460.png
#  extracting: train-images/448.png
#  extracting: train-images/1862.png
#  extracting: train-images/1876.png
#  extracting: train-images/1123.png
#  extracting: train-images/1645.png
#  extracting: train-images/1889.png
#  extracting: train-images/1651.png
#  extracting: train-images/1137.png
#  extracting: train-images/1679.png
#   inflating: train-images/110.png
#  extracting: train-images/1484.png
#   inflating: train-images/676.png
#  extracting: train-images/662.png
#   inflating: train-images/1490.png
#  extracting: train-images/104.png
#  extracting: train-images/892.png
#  extracting: train-images/886.png
#  extracting: train-images/138.png
#   inflating: train-images/1447.png
#  extracting: train-images/1321.png
#  extracting: train-images/879.png
#   inflating: train-images/1335.png
#   inflating: train-images/39.png
#  extracting: train-images/1453.png
#   inflating: train-images/851.png
#  extracting: train-images/689.png
#   inflating: train-images/11.png
#  extracting: train-images/845.png
#  extracting: train-images/1309.png
#  extracting: train-images/702.png
#  extracting: train-images/1296.png
#  extracting: train-images/1282.png
#   inflating: train-images/716.png
#  extracting: train-images/1533.png
#  extracting: train-images/1255.png
#   inflating: train-images/919.png
#  extracting: train-images/1241.png
#  extracting: train-images/1527.png
#  extracting: train-images/1269.png
#  extracting: train-images/925.png
#  extracting: train-images/931.png
#  extracting: train-images/1094.png
#  extracting: train-images/500.png
#  extracting: train-images/266.png
#  extracting: train-images/272.png
#  extracting: train-images/514.png
#  extracting: train-images/1080.png
#   inflating: train-images/1916.png
#   inflating: train-images/1902.png
#  extracting: train-images/528.png
#  extracting: train-images/1057.png
#  extracting: train-images/1731.png
#  extracting: train-images/1725.png
#  extracting: train-images/1043.png
#   inflating: train-images/299.png
#  extracting: train-images/1719.png
#  extracting: train-images/1718.png
#   inflating: train-images/298.png
#  extracting: train-images/1724.png
#  extracting: train-images/1042.png
#  extracting: train-images/1056.png
#  extracting: train-images/1730.png
#  extracting: train-images/1903.png
#   inflating: train-images/529.png
#   inflating: train-images/1917.png
#   inflating: train-images/273.png
#  extracting: train-images/1081.png
#   inflating: train-images/515.png
#  extracting: train-images/501.png
#  extracting: train-images/1095.png
#  extracting: train-images/267.png
#  extracting: train-images/930.png
#  extracting: train-images/924.png
#   inflating: train-images/1268.png
#  extracting: train-images/1240.png
#  extracting: train-images/1526.png
#  extracting: train-images/1532.png
#  extracting: train-images/918.png
#  extracting: train-images/1254.png
#  extracting: train-images/717.png
#  extracting: train-images/1283.png
#  extracting: train-images/1297.png
#  extracting: train-images/703.png
#  extracting: train-images/1308.png
#  extracting: train-images/844.png
#  extracting: train-images/10.png
#   inflating: train-images/688.png
#   inflating: train-images/850.png
#  extracting: train-images/38.png
#  extracting: train-images/1334.png
#   inflating: train-images/878.png
#  extracting: train-images/1452.png
#   inflating: train-images/1446.png
#   inflating: train-images/1320.png
#  extracting: train-images/887.png
#  extracting: train-images/139.png
#  extracting: train-images/893.png
#  extracting: train-images/663.png
#  extracting: train-images/105.png
#   inflating: train-images/1491.png
#  extracting: train-images/1485.png
#   inflating: train-images/111.png
#  extracting: train-images/677.png
#  extracting: train-images/1678.png
#  extracting: train-images/1650.png
#  extracting: train-images/1888.png
#   inflating: train-images/1136.png
#  extracting: train-images/1122.png
#  extracting: train-images/1644.png
#  extracting: train-images/1877.png
#  extracting: train-images/449.png
#   inflating: train-images/1863.png
#  extracting: train-images/1693.png
#  extracting: train-images/307.png
#   inflating: train-images/461.png
#  extracting: train-images/475.png
#   inflating: train-images/313.png
#  extracting: train-images/1687.png
#  extracting: train-images/1846.png
#   inflating: train-images/478.png
#  extracting: train-images/1852.png
#   inflating: train-images/336.png
#  extracting: train-images/450.png
#  extracting: train-images/444.png
#   inflating: train-images/322.png
#   inflating: train-images/1885.png
#  extracting: train-images/1891.png
#  extracting: train-images/1649.png
#   inflating: train-images/1661.png
#  extracting: train-images/493.png
#  extracting: train-images/1107.png
#  extracting: train-images/1113.png
#   inflating: train-images/487.png
#  extracting: train-images/1675.png
#   inflating: train-images/108.png
#  extracting: train-images/1488.png
#  extracting: train-images/652.png
#  extracting: train-images/134.png
#  extracting: train-images/120.png
#  extracting: train-images/646.png
#  extracting: train-images/875.png
#  extracting: train-images/35.png
#  extracting: train-images/1339.png
#   inflating: train-images/861.png
#   inflating: train-images/21.png
#   inflating: train-images/849.png
#  extracting: train-images/1305.png
#  extracting: train-images/691.png
#  extracting: train-images/1463.png
#  extracting: train-images/1477.png
#   inflating: train-images/685.png
#  extracting: train-images/1311.png
#   inflating: train-images/726.png
#  extracting: train-images/732.png
#  extracting: train-images/901.png
#  extracting: train-images/1259.png
#  extracting: train-images/915.png
#  extracting: train-images/1271.png
#  extracting: train-images/1517.png
#   inflating: train-images/1503.png
#  extracting: train-images/1265.png
#   inflating: train-images/929.png
#  extracting: train-images/1932.png
#  extracting: train-images/518.png
#   inflating: train-images/1098.png
#  extracting: train-images/1926.png
#  extracting: train-images/242.png
#  extracting: train-images/524.png
#   inflating: train-images/530.png
#   inflating: train-images/256.png
#  extracting: train-images/1729.png
#   inflating: train-images/281.png
#  extracting: train-images/1715.png
#   inflating: train-images/1073.png
#  extracting: train-images/1067.png
#  extracting: train-images/1701.png
#   inflating: train-images/295.png
#  extracting: train-images/1066.png
#  extracting: train-images/294.png
#  extracting: train-images/1700.png
#  extracting: train-images/1714.png
#  extracting: train-images/280.png
#   inflating: train-images/1072.png
#  extracting: train-images/1728.png
#  extracting: train-images/531.png
#   inflating: train-images/257.png
#   inflating: train-images/243.png
#   inflating: train-images/525.png
#  extracting: train-images/1099.png
#  extracting: train-images/1927.png
#  extracting: train-images/1933.png
#   inflating: train-images/519.png
#  extracting: train-images/1502.png
#   inflating: train-images/928.png
#  extracting: train-images/1264.png
#  extracting: train-images/1270.png
#  extracting: train-images/1516.png
#  extracting: train-images/914.png
#   inflating: train-images/1258.png
#  extracting: train-images/900.png
#  extracting: train-images/733.png
#   inflating: train-images/727.png
#  extracting: train-images/1476.png
#  extracting: train-images/1310.png
#   inflating: train-images/684.png
#  extracting: train-images/690.png
#  extracting: train-images/1304.png
#  extracting: train-images/848.png
#  extracting: train-images/1462.png
#  extracting: train-images/20.png
#  extracting: train-images/860.png
#  extracting: train-images/1338.png
#   inflating: train-images/34.png
#  extracting: train-images/874.png
#  extracting: train-images/121.png
#   inflating: train-images/647.png
#  extracting: train-images/653.png
#  extracting: train-images/135.png
#  extracting: train-images/1489.png
#   inflating: train-images/109.png
#   inflating: train-images/486.png
#  extracting: train-images/1112.png
#   inflating: train-images/1674.png
#   inflating: train-images/1660.png
#  extracting: train-images/1106.png
#  extracting: train-images/492.png
#   inflating: train-images/1648.png
#  extracting: train-images/1890.png
#  extracting: train-images/1884.png
#  extracting: train-images/445.png
#   inflating: train-images/323.png
#   inflating: train-images/337.png
#  extracting: train-images/451.png
#   inflating: train-images/479.png
#  extracting: train-images/1853.png
#  extracting: train-images/1847.png
#   inflating: train-images/1689.png
#  extracting: train-images/1851.png
#  extracting: train-images/309.png
#  extracting: train-images/1845.png
#  extracting: train-images/321.png
#  extracting: train-images/447.png
#   inflating: train-images/453.png
#   inflating: train-images/335.png
#  extracting: train-images/1879.png
#  extracting: train-images/1892.png
#  extracting: train-images/1138.png
#   inflating: train-images/1886.png
#  extracting: train-images/1676.png
#  extracting: train-images/1110.png
#   inflating: train-images/484.png
#  extracting: train-images/490.png
#   inflating: train-images/1104.png
#   inflating: train-images/1662.png
#  extracting: train-images/679.png
#  extracting: train-images/645.png
#  extracting: train-images/123.png
#   inflating: train-images/137.png
#  extracting: train-images/651.png
#   inflating: train-images/889.png
#   inflating: train-images/862.png
#  extracting: train-images/22.png
#  extracting: train-images/1448.png
#  extracting: train-images/876.png
#  extracting: train-images/36.png
#   inflating: train-images/686.png
#  extracting: train-images/1312.png
#  extracting: train-images/1474.png
#  extracting: train-images/1460.png
#   inflating: train-images/1306.png
#  extracting: train-images/692.png
#  extracting: train-images/1299.png
#  extracting: train-images/719.png
#  extracting: train-images/731.png
#   inflating: train-images/725.png
#  extracting: train-images/916.png
#  extracting: train-images/1528.png
#  extracting: train-images/902.png
#  extracting: train-images/1266.png
#  extracting: train-images/1500.png
#  extracting: train-images/1514.png
#  extracting: train-images/1272.png
#   inflating: train-images/1925.png
#  extracting: train-images/269.png
#  extracting: train-images/1931.png
#  extracting: train-images/1919.png
#   inflating: train-images/255.png
#  extracting: train-images/533.png
#  extracting: train-images/527.png
#  extracting: train-images/241.png
#  extracting: train-images/1058.png
#  extracting: train-images/1702.png
#   inflating: train-images/296.png
#   inflating: train-images/1064.png
#  extracting: train-images/1070.png
#   inflating: train-images/282.png
#  extracting: train-images/1716.png
#  extracting: train-images/1071.png
#  extracting: train-images/1717.png
#   inflating: train-images/283.png
#   inflating: train-images/297.png
#   inflating: train-images/1703.png
#   inflating: train-images/1065.png
#  extracting: train-images/1059.png
#  extracting: train-images/526.png
#   inflating: train-images/240.png
#  extracting: train-images/254.png
#  extracting: train-images/1918.png
#  extracting: train-images/532.png
#  extracting: train-images/1930.png
#  extracting: train-images/268.png
#   inflating: train-images/1924.png
#  extracting: train-images/1515.png
#  extracting: train-images/1273.png
#  extracting: train-images/1267.png
#  extracting: train-images/1501.png
#  extracting: train-images/1529.png
#   inflating: train-images/903.png
#  extracting: train-images/917.png
#  extracting: train-images/724.png
#  extracting: train-images/730.png
#  extracting: train-images/718.png
#  extracting: train-images/1298.png
#  extracting: train-images/1461.png
#   inflating: train-images/693.png
#  extracting: train-images/1307.png
#  extracting: train-images/1313.png
#   inflating: train-images/687.png
#  extracting: train-images/1475.png
#   inflating: train-images/37.png
#   inflating: train-images/877.png
#  extracting: train-images/23.png
#  extracting: train-images/863.png
#  extracting: train-images/1449.png
#   inflating: train-images/136.png
#   inflating: train-images/888.png
#  extracting: train-images/650.png
#  extracting: train-images/644.png
#  extracting: train-images/122.png
#  extracting: train-images/678.png
#  extracting: train-images/1105.png
#  extracting: train-images/491.png
#   inflating: train-images/1663.png
#  extracting: train-images/1677.png
#   inflating: train-images/485.png
#  extracting: train-images/1111.png
#  extracting: train-images/1139.png
#  extracting: train-images/1887.png
#  extracting: train-images/1893.png
#   inflating: train-images/452.png
#  extracting: train-images/1878.png
#   inflating: train-images/334.png
#  extracting: train-images/320.png
#  extracting: train-images/446.png
#  extracting: train-images/1844.png
#  extracting: train-images/308.png
#  extracting: train-images/1850.png
#   inflating: train-images/1688.png
#   inflating: train-images/442.png
#  extracting: train-images/324.png
#  extracting: train-images/1868.png
#   inflating: train-images/330.png
#  extracting: train-images/456.png
#   inflating: train-images/318.png
#  extracting: train-images/1854.png
#  extracting: train-images/1698.png
#  extracting: train-images/1840.png
#   inflating: train-images/1115.png
#  extracting: train-images/481.png
#   inflating: train-images/1673.png
#  extracting: train-images/1667.png
#  extracting: train-images/495.png
#  extracting: train-images/1101.png
#  extracting: train-images/1129.png
#  extracting: train-images/1897.png
#  extracting: train-images/1883.png
#  extracting: train-images/126.png
#  extracting: train-images/640.png
#  extracting: train-images/898.png
#  extracting: train-images/654.png
#   inflating: train-images/132.png
#  extracting: train-images/668.png
#  extracting: train-images/1471.png
#  extracting: train-images/683.png
#  extracting: train-images/1317.png
# ...
#  extracting: test-images/429.png
#   inflating: test-images/415.png
#  extracting: test-images/373.png
#  extracting: test-images/367.png
#  extracting: test-images/401.png
#  extracting: test-images/371.png
#   inflating: test-images/417.png
#  extracting: test-images/403.png
#  extracting: test-images/365.png
#  extracting: test-images/359.png
#  extracting: test-images/173.png
#  extracting: test-images/167.png
#  extracting: test-images/99.png
#  extracting: test-images/8.png
#  extracting: test-images/72.png
#  extracting: test-images/198.png
#   inflating: test-images/66.png
#   inflating: test-images/205.png
#  extracting: test-images/211.png
#  extracting: test-images/239.png
#  extracting: test-images/238.png
#   inflating: test-images/210.png
#   inflating: test-images/204.png
#  extracting: test-images/199.png
#   inflating: test-images/67.png
#  extracting: test-images/73.png
#  extracting: test-images/9.png
#  extracting: test-images/166.png
#  extracting: test-images/98.png
#  extracting: test-images/172.png
#  extracting: test-images/358.png
#  extracting: test-images/402.png
#  extracting: test-images/364.png
#  extracting: test-images/370.png
#   inflating: test-images/416.png
#   inflating: test-images/459.png
#  extracting: test-images/317.png
#  extracting: test-images/471.png
#  extracting: test-images/465.png
#   inflating: test-images/303.png
#   inflating: test-images/129.png
#  extracting: test-images/115.png
#  extracting: test-images/101.png
#  extracting: test-images/14.png
#  extracting: test-images/28.png
#   inflating: test-images/263.png
#   inflating: test-images/277.png
#  extracting: test-images/288.png
#  extracting: test-images/289.png
#   inflating: test-images/276.png
#  extracting: test-images/262.png
#  extracting: test-images/29.png
#  extracting: test-images/15.png
#  extracting: test-images/100.png
#   inflating: test-images/114.png
#   inflating: test-images/128.png
#  extracting: test-images/464.png
#  extracting: test-images/302.png
#   inflating: test-images/316.png
#  extracting: test-images/470.png
#   inflating: test-images/458.png
#  extracting: test-images/328.png
#  extracting: test-images/300.png
#  extracting: test-images/466.png
#  extracting: test-images/472.png
#  extracting: test-images/314.png
#   inflating: test-images/499.png
#  extracting: test-images/102.png
#  extracting: test-images/116.png
#  extracting: test-images/17.png
#  extracting: test-images/248.png
#   inflating: test-images/274.png
#  extracting: test-images/260.png
#  extracting: test-images/261.png
#   inflating: test-images/275.png
#  extracting: test-images/249.png
#  extracting: test-images/16.png
#  extracting: test-images/117.png
#  extracting: test-images/103.png
#   inflating: test-images/498.png
#  extracting: test-images/473.png
#  extracting: test-images/315.png
#   inflating: test-images/301.png
#  extracting: test-images/467.png
#  extracting: test-images/329.png
#   inflating: test-images/463.png
#   inflating: test-images/305.png
#  extracting: test-images/311.png
#  extracting: test-images/477.png
#  extracting: test-images/339.png
#  extracting: test-images/488.png
#   inflating: test-images/107.png
#  extracting: test-images/113.png
#  extracting: test-images/12.png
#   inflating: test-images/271.png
#   inflating: test-images/265.png
#  extracting: test-images/259.png
#  extracting: test-images/258.png
#   inflating: test-images/264.png
#   inflating: test-images/270.png
#  extracting: test-images/13.png
#   inflating: test-images/112.png
#  extracting: test-images/106.png
#  extracting: test-images/489.png
#  extracting: test-images/338.png
#  extracting: test-images/310.png
#  extracting: test-images/476.png
#   inflating: test-images/462.png
#   inflating: test-images/304.png
#  extracting: test-images/474.png
#  extracting: test-images/312.png
#   inflating: test-images/306.png
#  extracting: test-images/460.png
#  extracting: test-images/448.png
#   inflating: test-images/110.png
#  extracting: test-images/104.png
#   inflating: test-images/138.png
#   inflating: test-images/39.png
#  extracting: test-images/11.png
#   inflating: test-images/266.png
#   inflating: test-images/272.png
#   inflating: test-images/299.png
#   inflating: test-images/298.png
#   inflating: test-images/273.png
#  extracting: test-images/267.png
#  extracting: test-images/10.png
#   inflating: test-images/38.png
#   inflating: test-images/139.png
#  extracting: test-images/105.png
#   inflating: test-images/111.png
#  extracting: test-images/449.png
#  extracting: test-images/307.png
#   inflating: test-images/461.png
#  extracting: test-images/475.png
#  extracting: test-images/313.png
#  extracting: test-images/478.png
#  extracting: test-images/336.png
#  extracting: test-images/450.png
#  extracting: test-images/444.png
#  extracting: test-images/322.png
#   inflating: test-images/493.png
#  extracting: test-images/487.png
#  extracting: test-images/108.png
#   inflating: test-images/134.png
#  extracting: test-images/120.png
#  extracting: test-images/35.png
#  extracting: test-images/21.png
#  extracting: test-images/242.png
#  extracting: test-images/256.png
#  extracting: test-images/281.png
#   inflating: test-images/295.png
#  extracting: test-images/294.png
#   inflating: test-images/280.png
#  extracting: test-images/257.png
#  extracting: test-images/243.png
#  extracting: test-images/20.png
#  extracting: test-images/34.png
#  extracting: test-images/121.png
#   inflating: test-images/135.png
#   inflating: test-images/109.png
#  extracting: test-images/486.png
#   inflating: test-images/492.png
#  extracting: test-images/445.png
#   inflating: test-images/323.png
#  extracting: test-images/337.png
#  extracting: test-images/451.png
#  extracting: test-images/479.png
#  extracting: test-images/309.png
#  extracting: test-images/321.png
#  extracting: test-images/447.png
#  extracting: test-images/453.png
#  extracting: test-images/335.png
#  extracting: test-images/484.png
#  extracting: test-images/490.png
#  extracting: test-images/123.png
#   inflating: test-images/137.png
#  extracting: test-images/22.png
#   inflating: test-images/36.png
#   inflating: test-images/269.png
#  extracting: test-images/255.png
#  extracting: test-images/241.png
#   inflating: test-images/296.png
#  extracting: test-images/282.png
#  extracting: test-images/283.png
#   inflating: test-images/297.png
#  extracting: test-images/240.png
#  extracting: test-images/254.png
#   inflating: test-images/268.png
#   inflating: test-images/37.png
#  extracting: test-images/23.png
#   inflating: test-images/136.png
#  extracting: test-images/122.png
#   inflating: test-images/491.png
#  extracting: test-images/485.png
#  extracting: test-images/452.png
#  extracting: test-images/334.png
#   inflating: test-images/320.png
#  extracting: test-images/446.png
#  extracting: test-images/308.png
#  extracting: test-images/442.png
#  extracting: test-images/324.png
#  extracting: test-images/330.png
#   inflating: test-images/456.png
#   inflating: test-images/318.png
#  extracting: test-images/481.png
#   inflating: test-images/495.png
#   inflating: test-images/126.png
#   inflating: test-images/132.png
#  extracting: test-images/27.png
#  extracting: test-images/33.png
#  extracting: test-images/250.png
#  extracting: test-images/244.png
#   inflating: test-images/278.png
#   inflating: test-images/293.png
#  extracting: test-images/287.png
#  extracting: test-images/286.png
#  extracting: test-images/292.png
#   inflating: test-images/279.png
#  extracting: test-images/245.png
#  extracting: test-images/251.png
#  extracting: test-images/32.png
#  extracting: test-images/26.png
#   inflating: test-images/133.png
#   inflating: test-images/127.png
#   inflating: test-images/494.png
#  extracting: test-images/480.png
#   inflating: test-images/319.png
#  extracting: test-images/331.png
#  extracting: test-images/457.png
#  extracting: test-images/443.png
#  extracting: test-images/325.png
#  extracting: test-images/455.png
#  extracting: test-images/333.png
#  extracting: test-images/327.png
#  extracting: test-images/441.png
#  extracting: test-images/469.png
#   inflating: test-images/496.png
#  extracting: test-images/482.png
#   inflating: test-images/131.png
#   inflating: test-images/125.png
#  extracting: test-images/119.png
#  extracting: test-images/18.png
#  extracting: test-images/30.png
#  extracting: test-images/24.png
#  extracting: test-images/247.png
#  extracting: test-images/253.png
#  extracting: test-images/284.png
#   inflating: test-images/290.png
#   inflating: test-images/291.png
#  extracting: test-images/285.png
#  extracting: test-images/252.png
#  extracting: test-images/246.png
#  extracting: test-images/25.png
#  extracting: test-images/31.png
#  extracting: test-images/19.png
#  extracting: test-images/118.png
#   inflating: test-images/124.png
#   inflating: test-images/130.png
#  extracting: test-images/483.png
#   inflating: test-images/497.png
#  extracting: test-images/468.png
#  extracting: test-images/326.png
#  extracting: test-images/440.png
#  extracting: test-images/454.png
#  extracting: test-images/332.png
#  extracting: test-images/369.png
#   inflating: test-images/433.png
#  extracting: test-images/355.png
#  extracting: test-images/341.png
#  extracting: test-images/427.png
#  extracting: test-images/396.png
#  extracting: test-images/382.png
#   inflating: test-images/95.png
#  extracting: test-images/81.png
#  extracting: test-images/157.png
#  extracting: test-images/143.png
#  extracting: test-images/4.png
#  extracting: test-images/56.png
#   inflating: test-images/42.png
#  extracting: test-images/194.png
#  extracting: test-images/180.png
#   inflating: test-images/209.png
#   inflating: test-images/221.png
#  extracting: test-images/235.png
#  extracting: test-images/234.png
#  extracting: test-images/220.png
#   inflating: test-images/208.png
#  extracting: test-images/181.png
#  extracting: test-images/195.png
#   inflating: test-images/43.png
#  extracting: test-images/5.png
#  extracting: test-images/57.png
#  extracting: test-images/142.png
#  extracting: test-images/156.png
#  extracting: test-images/80.png
#   inflating: test-images/94.png
#  extracting: test-images/383.png
#  extracting: test-images/397.png
#  extracting: test-images/340.png
#  extracting: test-images/426.png
#   inflating: test-images/432.png
#  extracting: test-images/354.png
#  extracting: test-images/368.png
#   inflating: test-images/418.png
#  extracting: test-images/424.png
#   inflating: test-images/342.png
#  extracting: test-images/356.png
#   inflating: test-images/430.png
#  extracting: test-images/381.png
#  extracting: test-images/395.png
#  extracting: test-images/82.png
#  extracting: test-images/96.png
#  extracting: test-images/168.png
#   inflating: test-images/140.png
#  extracting: test-images/154.png
#   inflating: test-images/41.png
#  extracting: test-images/55.png
#  extracting: test-images/7.png
#  extracting: test-images/183.png
#   inflating: test-images/69.png
#  extracting: test-images/197.png
#  extracting: test-images/236.png
#  extracting: test-images/222.png
#  extracting: test-images/223.png
#  extracting: test-images/237.png
#   inflating: test-images/68.png
#  extracting: test-images/196.png
#  extracting: test-images/182.png
#  extracting: test-images/54.png
#  extracting: test-images/6.png
#   inflating: test-images/40.png
#  extracting: test-images/155.png
#   inflating: test-images/141.png
#   inflating: test-images/97.png
#  extracting: test-images/169.png
#  extracting: test-images/83.png
#  extracting: test-images/394.png
#  extracting: test-images/380.png
#  extracting: test-images/357.png
#   inflating: test-images/431.png
#  extracting: test-images/425.png
#   inflating: test-images/343.png
#   inflating: test-images/419.png
#   inflating: test-images/347.png
#   inflating: test-images/421.png
#   inflating: test-images/435.png
#  extracting: test-images/353.png
#  extracting: test-images/409.png
#  extracting: test-images/384.png
#  extracting: test-images/390.png
#  extracting: test-images/145.png
#  extracting: test-images/151.png
#  extracting: test-images/87.png
#  extracting: test-images/179.png
#   inflating: test-images/93.png
#  extracting: test-images/78.png
#  extracting: test-images/186.png
#  extracting: test-images/192.png
#   inflating: test-images/44.png
#  extracting: test-images/2.png
#  extracting: test-images/50.png
#  extracting: test-images/233.png
#  extracting: test-images/227.png
#  extracting: test-images/226.png
#  extracting: test-images/232.png
#  extracting: test-images/3.png
#  extracting: test-images/51.png
#  extracting: test-images/45.png
#  extracting: test-images/193.png
#  extracting: test-images/79.png
#  extracting: test-images/187.png
#  extracting: test-images/92.png
#  extracting: test-images/86.png
#  extracting: test-images/178.png
#  extracting: test-images/150.png
#  extracting: test-images/144.png
#  extracting: test-images/391.png
#  extracting: test-images/385.png
#  extracting: test-images/408.png
#   inflating: test-images/434.png
#  extracting: test-images/352.png
#   inflating: test-images/346.png
#   inflating: test-images/420.png
#  extracting: test-images/350.png
#   inflating: test-images/436.png
#  extracting: test-images/422.png
#   inflating: test-images/344.png
#  extracting: test-images/378.png
#  extracting: test-images/393.png
#  extracting: test-images/387.png
#  extracting: test-images/152.png
#  extracting: test-images/146.png
#  extracting: test-images/90.png
#  extracting: test-images/84.png
#  extracting: test-images/191.png
#  extracting: test-images/185.png
#  extracting: test-images/53.png
#  extracting: test-images/1.png
#  extracting: test-images/47.png
#  extracting: test-images/224.png
#  extracting: test-images/230.png
#  extracting: test-images/218.png
#  extracting: test-images/219.png
#  extracting: test-images/231.png
#  extracting: test-images/225.png
#  extracting: test-images/46.png
#  extracting: test-images/52.png
#  extracting: test-images/0.png
#  extracting: test-images/184.png
#  extracting: test-images/190.png
#  extracting: test-images/85.png
#   inflating: test-images/91.png
#  extracting: test-images/147.png
#  extracting: test-images/153.png
#  extracting: test-images/386.png
#  extracting: test-images/392.png
#  extracting: test-images/379.png
#  extracting: test-images/423.png
#   inflating: test-images/345.png
#  extracting: test-images/351.png
#   inflating: test-images/437.png

# %% [markdown]
# # Handling the data

# %%
# # Load the train labels
# # Note the transpose!
labels_train = pd.read_csv("y_train.csv", index_col=0).T

# %%
# Here is a function to load the data
def load_dataset(dataset_dir):
    dataset_list = []
    # Note: It's very important to load the images in the correct numerical order!
    for image_file in list(sorted(Path(dataset_dir).glob("*.png"), key=lambda filename: int(filename.name.rstrip(".png")))):
        dataset_list.append(cv2.imread(str(image_file), cv2.IMREAD_GRAYSCALE))
    return np.stack(dataset_list, axis=0)

# %%
# Load the train and test sets
# If you've put the shortcut directly in your drive, this should work out of the box
# Else, edit the path
data_dir = Path("./")
data_train = load_dataset(data_dir / "train-images")
# data_test = load_dataset(data_dir / "test-images")

# labeled_train_data = data_train[:800]
unlabeled_train_data = data_train[800:]
# labeled_train_labels = labels_train[:800]
unlabeled_train_labels = labels_train[800:]

# %%
# The train data is a numpy array of 1000 images of 512*512
print(f"X_train shape: {data_train.shape}")
# The train label is a dataframe of 1000 rows with 262144 (=512x512) columns
print(f"Y_train shape: {labels_train.shape}")
# Out:
# X_train shape: (2000, 256, 256)
# Y_train shape: (2000, 65536)

# %%
# Let's display some data
# Here is a function to display side by side a slide and a segmented mask
def plot_slice_seg(slice_image, seg):
    fig, axes = plt.subplots(1, 2)
    axes[0].imshow(slice_image, cmap="gray")
    axes[1].imshow(slice_image, cmap="gray")
    seg_masked = np.ma.masked_where(seg.reshape((256,256)) == 0, (seg.reshape((256,256))))
    axes[1].imshow(seg_masked, cmap="tab20")
    plt.axis("off")

# Let's try it on a slide and ites segmentation mask
# Note: we have to reshape the rows of the dataframe into a 256*256 matrix
# plot_slice_seg(data_train[0], labels_train.iloc[0].values.reshape((256,256)))

# %% [markdown]
# # Let's compute a baseline

# %%
# Let's take a very basic watershed baseline
def compute_baseline_one_sample(data_slice):
    edges = sobel(data_slice)
    denoised = rank.median(data_slice, disk(2))
    markers = rank.gradient(denoised, disk(5)) < 20
    markers = ndi.label(markers)[0]
    label_predicted = watershed(edges, markers=markers, compactness=0.0001)
    return label_predicted

# %%
# Let's display the results
# Not too bad!
# plot_slice_seg(data_train[2], compute_baseline_one_sample(data_train[2]))

# %% [markdown]
# ## Let's measure its performances

# %%
# Compute the baseline on a whole dataset
def compute_baseline(dataset: np.array):
    labels_predicted_list = []
    for data_index in tqdm(range(len(dataset))):
        data_slice = dataset[data_index]
        label_predicted = compute_baseline_one_sample(data_slice)
        labels_predicted_list.append(label_predicted)
    return pd.DataFrame(np.stack(labels_predicted_list, axis=0).reshape((len(labels_predicted_list), -1)))

# %%
# Let's create a validation set first: the 200 first images of the train set
data_val = data_train[:200]
labels_val = labels_train.iloc[:200]

# %%
# Compute baseline on a few train data
# labels_val_predicted_baseline = compute_baseline(data_val)

# %%
NUM_CLASSES = 54 # 55 classes in total, but the first one is the background


def dice_image(prediction, ground_truth):
    intersection = np.sum(prediction * ground_truth)
    if np.sum(prediction) == 0 and np.sum(ground_truth) == 0:
        return np.nan
    return 2 * intersection / (np.sum(prediction) + np.sum(ground_truth))


def dice_multiclass(prediction, ground_truth):
    dices = []
    for i in range(1, NUM_CLASSES + 1): # skip background
        dices.append(dice_image(prediction == i, ground_truth == i))
    return np.array(dices)

def dice_pandas(y_true_df: pd.DataFrame, y_pred_df: pd.DataFrame) -> float:
    """Compute the dice score for each sample in the dataset and then average it"""
    y_pred_df = y_pred_df.T
    y_true_df = y_true_df.T
    individual_dice = []
    for row_index in range(y_true_df.values.shape[0]):
        dices = dice_multiclass(y_true_df.values[row_index].ravel(), y_pred_df.values[row_index].ravel())
        individual_dice.append(dices)

    final = np.stack(individual_dice)
    # First, average over images for each class
    # Then, average over classes
    cls_dices = np.nanmean(final, axis=0)
    return float(np.nanmean(cls_dices))

# %%
# Compute the metric on the validation set
# dice_pandas(labels_val, labels_val_predicted_baseline)
# We get => (0.0011196021617737601); Not so bad, but room for improvements!
# Let's see if you can do better!

# %%
from transformers import AutoImageProcessor, AutoModel
from PIL import Image
import requests
import torch
import torchvision.transforms as T
from PIL import Image
import numpy as np
from torch.utils.data import Dataset, DataLoader

# %%
# Define preprocessing transforms
transform = T.Compose([
    T.Resize(224),  # Resize to DINOv2 expected input size
    T.ToTensor(),  # Convert to tensor
    T.Normalize(mean=[0.5, 0.5, 0.5], std=[0.25, 0.25, 0.25])  # Normalize
])
# transform = T.Compose([
#     T.Resize(224),
#     T.CenterCrop(224),
#     T.ToTensor(),
#     T.Normalize(mean=[0.5], std=[0.5]),
# ])

def preprocess_image(image_array):
    """
    Convert grayscale (256x256) CT scan to a format usable by DINOv2.
    - image_array: NumPy array of shape (256, 256), values in range [0,1].
    - Returns: Tensor of shape (3, 224, 224) ready for DINOv2.
    """
    img = np.stack([image_array] * 3, axis=-1)  # Convert grayscale (H,W) → RGB (H,W,3)
    img = Image.fromarray((img * 255).astype(np.uint8))  # Convert to PIL image
    img = transform(img)  # Apply resizing and normalization
    return img

model = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitg14')
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitg14/dinov2_vitg14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitg14_pretrain.pth
# 100%|██████████| 4.23G/4.23G [00:43<00:00, 105MB/s]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# Custom dataset class for multiple grayscale CT scans
class CTDataset(Dataset):
    def __init__(self, images):
        """
        images: A list or NumPy array of shape (N, 256, 256) containing grayscale CT scans.
        """
        self.images = images

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]  # Get (256, 256) image
        #return img
        return preprocess_image(img)  # Convert to 3-channel 224x224 tensor

# # Load dataset (replace `ct_scan_data` with your actual dataset)
train_dataset = CTDataset(unlabeled_train_data)  # `ct_scan_data` should be (N, 256, 256)
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=False, num_workers=4)

valid_dataset = CTDataset(data_val)
valid_dataloader = DataLoader(valid_dataset, batch_size=8, shuffle=False, num_workers=4)

all_dataset = CTDataset(data_train)
all_dataloader = DataLoader(all_dataset, batch_size=8, shuffle=False, num_workers=4)
# # Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")



# Extract features for all images
# train_patch_features_list = []
# train_cls_features_list = []
# with torch.no_grad():
#     for batch in tqdm(train_dataloader):
#         batch = batch.to(device)
#         features_dict = model.forward_features(batch)
#         #print(features_dict)
#         patch_features = features_dict["x_norm_patchtokens"]  # Patch features
#         cls_features = features_dict["x_norm_clstoken"]  # Patch features
#         train_patch_features_list.append(patch_features)
#         train_cls_features_list.append(cls_features)
#         #train_features_list.append(features.cpu().numpy())

# valid_patch_features_list = []
# valid_cls_features_list = []
# with torch.no_grad():
#     for batch in tqdm(valid_dataloader):
#         batch = batch.to(device)
#         features_dict = model.forward_features(batch)
#         patch_features = features_dict["x_norm_patchtokens"]  # Patch features
#         cls_features = features_dict["x_norm_clstoken"]  # Patch features
#         valid_patch_features_list.append(patch_features)
#         valid_cls_features_list.append(cls_features)


all_patch_features_list = []
all_cls_features_list = []
with torch.no_grad():
    for batch in tqdm(all_dataloader):
        batch = batch.to(device)
        model.to(device)
        features_dict = model.forward_features(batch)
        patch_features = features_dict["x_norm_patchtokens"]  # Patch features
        cls_features = features_dict["x_norm_clstoken"]  # Patch features
        all_patch_features_list.append(patch_features)
        all_cls_features_list.append(cls_features)



# Reduce dimensionality with PCA (for visualization)
#patch_features = torch.cat(train_patch_features_list, dim=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 250/250 [07:08<00:00,  1.71s/it]

# %%
import torchvision.transforms as transforms
import torchvision.transforms.functional as F
print(all_patch_features_list[0].shape)
b_patch_features = all_patch_features_list[0][1]
pca = PCA(n_components=3)
pca_features = pca.fit_transform(b_patch_features.squeeze(0).cpu().numpy())

# Normalize PCA features for visualization
pca_features = (pca_features - pca_features.min()) / (pca_features.max() - pca_features.min())
pca_features = (pca_features * 255).astype(np.uint8)

# Visualize the extracted features as an image
plt.imshow(pca_features.reshape(16, 16, 3))
plt.show()
plt.axis("off")
plt.savefig('meta_dog_features.png')
plt.imshow(data_train[0])


#finetuning for model on our unlabeled data... work in progress
# teacher_model = AutoModel.from_pretrained('facebook/dinov2-large')
# student_model = AutoModel.from_pretrained('facebook/dinov2-large')
# teacher_model = AutoModel.from_pretrained('facebook/dinov2-base')
# student_model = AutoModel.from_pretrained('facebook/dinov2-base')
# optimizer = torch.optim.AdamW(student_model.parameters(), lr=1e-6, weight_decay=1e-4)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# teacher_model.to(device)
# student_model.to(device)
# scaler = torch.cuda.amp.GradScaler()  # Enable mixed precision
# # Disable gradients for the teacher model
# for param in teacher_model.parameters():
#     param.requires_grad = False
def tensor_to_pil(tensor):
    """Convert a single torch.Tensor image to PIL Image."""
    return transforms.ToPILImage()(tensor.cpu())

def augment_tensor(batch):
    """Applies random augmentations directly to a batch of images."""
    batch = F.resize(batch, (224, 224))  # Resize the whole batch at once

    if torch.rand(1) < 0.5:
        batch = F.hflip(batch)  # Random horizontal flip

    if torch.rand(1) < 0.2:
        batch = F.gaussian_blur(batch, kernel_size=(3, 3))  # Random blur

    return batch

def update_teacher(student_model, teacher_model, momentum=0.996):
    """Updates teacher model weights using EMA of student model weights."""
    for student_param, teacher_param in zip(student_model.parameters(), teacher_model.parameters()):
        teacher_param.data = momentum * teacher_param.data + (1 - momentum) * student_param.data

def dino_loss(student_output, teacher_output, temperature=0.5):
    """Computes contrastive loss between student and teacher outputs."""
    student_features = student_output.last_hidden_state  # Extract tensor

    # ✅ Fix: Center logits before applying softmax
    student_features = student_features - student_features.max(dim=-1, keepdim=True)[0]
    teacher_features = teacher_output - teacher_output.max(dim=-1, keepdim=True)[0]
    # Compute L2 distance between student and teacher features
    diff = torch.norm(student_features - teacher_features, dim=-1)
    print("Feature Difference Norm:", diff.mean().item())
    # Compute softmax
    student_probs = torch.nn.functional.softmax(student_features / temperature, dim=-1)
    teacher_probs = torch.nn.functional.softmax(teacher_features / temperature, dim=-1)
    print("Student Probs Min:", student_probs.min().item(), "Max:", student_probs.max().item())
    print("Teacher Probs Min:", teacher_probs.min().item(), "Max:", teacher_probs.max().item())

    # student_probs = torch.nn.functional.softmax(student_features / temperature, dim=-1)
    # teacher_probs = torch.nn.functional.softmax(teacher_output / temperature, dim=-1)



    return -torch.mean(torch.sum(teacher_probs * torch.log(student_probs), dim=-1))

# num_epochs = 20  # Number of fine-tuning epochs
# student_model.train()
# teacher_model.eval()  # Teacher is frozen

# for epoch in range(num_epochs):
#     total_loss = 0.0
#     progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{num_epochs}")

#     for batch in progress_bar:
#         batch = batch.to(device)
#         with torch.cuda.amp.autocast():

#           # Generate two different augmentations of the same image
#           view_1 = augment_tensor(batch)

#           view_2 = augment_tensor(batch)

#           # Forward pass (Student)
#           student_out_1 = student_model(view_1)
#           student_out_2 = student_model(view_2)

#           # Forward pass (Teacher) - No gradients
#           with torch.no_grad():
#               teacher_out_1 = teacher_model(view_1).last_hidden_state.detach()
#               teacher_out_2 = teacher_model(view_2).last_hidden_state.detach()

#           # Compute DINO loss
#           if torch.isnan(student_out_1.last_hidden_state).any():
#               print("Student output contains NaN!")
#           if torch.isnan(student_out_2.last_hidden_state).any():
#               print("Student output contains NaN!")

#           if torch.isnan(teacher_out_1).any():
#               print("Teacher output contains NaN!")
#           if torch.isnan(teacher_out_2).any():
#               print("Teacher output contains NaN!")
#           loss = (dino_loss(student_out_1, teacher_out_1) + dino_loss(student_out_2, teacher_out_2)) / 2
#           scaler.scale(loss).backward()
#           scaler.step(optimizer)
#           scaler.update()
#           # Backpropagation
#           # optimizer.zero_grad()
#           # loss.backward()
#           # optimizer.step()
#           scheduler.step()



#           # Update teacher model using EMA
#           update_teacher(student_model, teacher_model, momentum=0.996)

#           for name, param in student_model.named_parameters():
#             if param.grad is not None:
#                 print(f"{name} Grad Norm: {param.grad.norm().item()}")

#           total_loss += loss.item()
#           progress_bar.set_postfix({"Loss": loss.item()})

#     print(f"Epoch {epoch+1} Loss: {total_loss / len(train_dataloader)}")

# print("Finished fine-tuning DINOv2!")

# # import numpy as np

# # # Get mean & std across patches (excluding CLS token)
# # features_no_cls = all_features[:, :-1, :]  # Remove CLS token (shape: 128, 256, 1024)

# # print("Feature Mean:", np.mean(features_no_cls))
# # print("Feature Std:", np.std(features_no_cls))
# Out:
# torch.Size([8, 256, 1536])

# %%
#train and validation features are here
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
patch_features = torch.cat(all_patch_features_list, dim=0)
# cls_features = torch.cat(train_cls_features_list, dim=0)
cls_features = torch.cat(all_cls_features_list, dim=0)
print(patch_features.shape)
print(cls_features.shape)

print(len(all_cls_features_list))
# Assuming cls_features is a tensor of shape (num_images, 384)
cls_features_np = cls_features.cpu().numpy()  # Convert to NumPy

# Reduce 384D CLS features to 2D
pca = PCA(n_components=2)
cls_2d = pca.fit_transform(cls_features_np)

# Scatter plot
plt.scatter(cls_2d[:, 0], cls_2d[:, 1], alpha=0.7, edgecolors="k")
plt.xlabel("PCA Component 1")
plt.show()
# print(plt.imshow(data_train[1]))
# print(type(all_patch_features_list[0]))
# import torch

#tensor_list = [torch.randn(3, 3), torch.ones(5, 5), torch.zeros(2, 2)]  # Example tensor list
torch.save(patch_features, "all_patch_features.pth")  # Save to a file
torch.save(cls_features, "all_cls_features.pth")
# train_features = np.concatenate(train_features_list, axis=0)
# valid_features = np.concatenate(valid_features_list, axis=0)
# print("LABELS VAL SHAPE")
# print(labels_val.shape)
# print("TRAIN FEATURES SHAPE")
# print(train_features.shape)
# print("VALID FEATURES SHAPE")
# print(valid_features.shape)
# train_features_reshape = train_features.reshape(train_features.shape[0], -1)
# valid_features_reshape = valid_features.reshape(valid_features.shape[0], -1)
# print("TRAIN FEATURES RESHAPE SHAPE")
# print(train_features_reshape.shape)
# print("VALID FEATURES RESHAPE SHAPE")
# print(valid_features_reshape.shape)
# Out:
# torch.Size([2000, 256, 1536])
# torch.Size([2000, 1536])
# 250

# %%
from sklearn.cluster import KMeans
import numpy as np
import torch

NUM_CLASSES = 54  # Excluding background



# Merge all patch features into a single dataset (2000, 256, 384) → (512000, 384)

all_patch_features_np = torch.cat(all_patch_features_list, dim=0).reshape(-1, all_patch_features_list[0].shape[2]).cpu().numpy()

# Train K-Means ONCE
kmeans = KMeans(n_clusters=NUM_CLASSES, random_state=42, n_init=10)
kmeans.fit(all_patch_features_np)

# %%
# Example: Compute segmentation on one image
import cv2
print("Shape of training data:", all_patch_features_np.shape)  # Should be (512000, 384)
print("Data type:", all_patch_features_np.dtype)  # Should be float64
#print("First few rows:\n", all_patch_features_np[:5])  # Print sample rows
print("Min value:", np.min(all_patch_features_np), "Max value:", np.max(all_patch_features_np))  # Value range

def compute_kmeans_segmentation(features, kmeans_model):
    """Apply trained K-Means model to DINOv2 patch features to create segmentation masks."""
    D = features.shape[1]
    features_np = features.cpu().numpy().astype(np.float32)
    features_reshaped = features_np.reshape(-1, D)
    #features_reshaped = features.reshape(-1, D)  # Flatten to (num_patches, feature_dim)
    cluster_labels = kmeans_model.predict(features_reshaped)  # Use trained model

    # Reshape to (16, 16) before flattening
    segmentation_mask = cluster_labels.reshape(16, 16)

    # # Flatten to a 1D array
    # segmentation_mask = segmentation_mask.flatten()
    segmentation_mask = cv2.resize(segmentation_mask.astype(np.uint8), (256, 256), interpolation=cv2.INTER_NEAREST)
    return segmentation_mask
a_patch_features = patch_features[0]  # Shape: (16, 16, 384)
print(a_patch_features.shape)
predicted_kmeans_mask = compute_kmeans_segmentation(a_patch_features, kmeans)



from tqdm import tqdm
import pandas as pd

def compute_feature_dice(dataset_features, ground_truth_masks, kmeans_model):
    """Compute Dice Score for K-Means segmentation over the dataset."""
    predicted_masks = []

    for index in tqdm(range(len(dataset_features))):
        features = dataset_features[index]  # Extract feature tensor
        predicted_mask = compute_kmeans_segmentation(features, kmeans_model)
        predicted_masks.append(predicted_mask)

    predicted_df = pd.DataFrame(np.stack(predicted_masks, axis=0).reshape((len(predicted_masks), -1)))
    return dice_pandas(ground_truth_masks, predicted_df)

# Compute Dice Score for K-Means
feature_dice_score = compute_feature_dice(patch_features[:200], labels_val, kmeans)
print(f"Feature-Based Dice Score: {feature_dice_score:.4f}")

# #proof of concept, using GMM / Kmeans to see if features help prediction, then compare to baseline.
# from sklearn.decomposition import PCA
# from sklearn.mixture import GaussianMixture

# # **1️⃣ Remove CLS Token** (Keeping only image patches)
# train_features_patches = train_features[:, 1:, :]  # (200, 256, 768)
# valid_features_patches = valid_features[:, 1:, :]  # (200, 256, 768)

# # **2️⃣ Reshape for PCA & Clustering**
# train_features_reshaped = train_features_patches.reshape(-1, 768)  # (51200, 768)
# valid_features_reshaped = valid_features_patches.reshape(-1, 768)  # (51200, 768)

# # **3️⃣ Apply PCA to Preserve 99% Variance**
# pca = PCA(n_components=0.99, random_state=42)  # Automatically keeps 99% variance
# train_features_pca = pca.fit_transform(train_features_reshaped)
# valid_features_pca = pca.transform(valid_features_reshaped)

# print(f"✅ PCA Applied - New Feature Shape: {train_features_pca.shape}")  # Should be smaller than (51200, 768)

# # **4️⃣ GMM Clustering on PCA-Reduced Features**
# num_clusters = NUM_CLASSES  # Same number as K-Means

# #running GMM takes a very long time
# #gmm = GaussianMixture(n_components=num_clusters, random_state=42)

# # Train GMM on PCA-reduced DINOv2 features
# gmm.fit(train_features_pca)

# # Predict clusters for validation set
# cluster_labels = gmm.predict(valid_features_pca)

# print("✅ GMM Clustering Complete - Cluster Labels Shape:", cluster_labels.shape)


# #Kmeans here
# # import numpy as np
# # from sklearn.cluster import KMeans
# # train_features_patches = train_features[:, 1:, :]  # (200, 256, 768)
# # valid_features_patches = valid_features[:, 1:, :]  # (200, 256, 768)

# # # **3️⃣ Reshape for Clustering**
# # train_features_reshaped = train_features_patches.reshape(-1, 768)  # (51200, 768)
# # valid_features_reshaped = valid_features_patches.reshape(-1, 768)  # (51200, 768)

# # # **4️⃣ K-Means Clustering**
# # # num_clusters = NUM_CLASSES
# # # kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
# # # kmeans.fit(train_features_reshaped)
# # # cluster_labels = kmeans.predict(valid_features_reshaped)



# # # Predict clusters for validation images
# # #cluster_labels = kmeans.predict(valid_features_reshaped)
# # # kmeans2 = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
# # # cluster_labels2 = kmeans2.fit_predict(valid_features_reshaped)  # (51200,)

# %%
# import numpy as np
# Compute Dice Score for DINO + K-Means segmentation
import torch.nn.functional as F
segmented_images = cluster_labels.reshape(200, 16, 16)  # (200, 16, 16)
# **6️⃣ Upsample to (200, 256, 256)**
segmented_images_tensor = torch.tensor(segmented_images).float().unsqueeze(1)  # (200, 1, 16, 16)
segmented_images_resized = F.interpolate(segmented_images_tensor, size=(256, 256), mode="nearest")  # (200, 1, 256, 256)
segmented_images_resized = segmented_images_resized.squeeze(1).numpy()  # Convert back to NumPy

# **7️⃣ Flatten to (200, 65536)**
segmented_images_flattened = segmented_images_resized.reshape(200, 65536)  # ✅ Final Shape

print("Final Segmented Labels Shape:", segmented_images_flattened.shape)  # Should be (200, 65536)


# segmented_images_resized = F.interpolate(segmented_images_tensor, size=(256, 256), mode="nearest")  # (200, 1, 256, 256)
# segmented_images_resized = segmented_images_resized.squeeze(1).numpy()  # Convert back to NumPy

# # **7️⃣ Flatten to (200, 65536)**
# segmented_images_flattened = segmented_images_resized.reshape(200, 65536)  # ✅ Final Shape

# print("Final Segmented Labels Shape:", segmented_images_flattened.shape)  # Should be (200, 65536)
# segmented_images_resized = F.interpolate(segmented_images_tensor, size=(256, 256), mode="nearest")
labels_val_predicted_dino_kmeans = pd.DataFrame(segmented_images_flattened)
dice_dino_kmeans = dice_pandas(labels_val, labels_val_predicted_dino_kmeans)
print("DINO + K-Means Dice Score:", dice_dino_kmeans)

# # Remove CLS token (keeps only 256 patch features per image)
# features_no_cls = all_features[:, :-1, :]  # Shape: (128, 256, 1024)

# # Reshape: each row is a patch's 1024D feature vector
# reshaped_features = features_no_cls.reshape(-1, 1024)  # Shape: (128 * 256, 1024)

# print("K-Means Input Shape:", reshaped_features.shape)  # Expected: (total_patches, feature_dim)
